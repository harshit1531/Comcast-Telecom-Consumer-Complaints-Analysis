# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
df= pd.read_csv('Comcast_telecom_complaints_data.csv')

# %%
df.head(10)
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
# 5   338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6   361148      Throttling service and unreasonable data caps  24-06-15
# 7   359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8   318072                           Comcast extended outages  06-01-15
# 9   371214  Comcast Raising Prices and Not Being Available...  28-06-15
#
#   Date_month_year         Time        Received Via      City       State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon    Maryland
# ...

# %%
df ['Date']= pd.to_datetime (df['Date'])

# %%
df ['Date_month_year']= pd.to_datetime (df['Date_month_year'])

# %%
df ['Time']= pd.to_datetime (df['Time'])

# %%
df.head(10)
# Out:
#   Ticket #                                 Customer Complaint       Date  \
# 0   250635                      Comcast Cable Internet Speeds 2015-04-22
# 1   223441       Payment disappear - service got disconnected 2015-04-08
# 2   242732                                  Speed and Service 2015-04-18
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4   307175         Comcast not working and no service to boot 2015-05-26
# 5   338519  ISP Charging for arbitrary data limits with ov... 2015-06-12
# 6   361148      Throttling service and unreasonable data caps 2015-06-24
# 7   359792  Comcast refuses to help troubleshoot and corre... 2015-06-23
# 8   318072                           Comcast extended outages 2015-06-01
# 9   371214  Comcast Raising Prices and Not Being Available... 2015-06-28
#
#   Date_month_year                Time        Received Via      City  \
# 0      2015-04-22 2022-10-19 15:53:50  Customer Care Call  Abingdon
# ...

# %%
df.shape
# Out:
# (2224, 11)

# %%
df['Date'].unique()
# Out:
# array(['2015-04-22T00:00:00.000000000', '2015-04-08T00:00:00.000000000',
#        '2015-04-18T00:00:00.000000000', '2015-05-07T00:00:00.000000000',
#        '2015-05-26T00:00:00.000000000', '2015-06-12T00:00:00.000000000',
#        '2015-06-24T00:00:00.000000000', '2015-06-23T00:00:00.000000000',
#        '2015-06-01T00:00:00.000000000', '2015-06-28T00:00:00.000000000',
#        '2015-04-24T00:00:00.000000000', '2015-05-06T00:00:00.000000000',
#        '2015-06-13T00:00:00.000000000', '2015-06-30T00:00:00.000000000',
#        '2015-06-27T00:00:00.000000000', '2015-04-16T00:00:00.000000000',
#        '2015-04-11T00:00:00.000000000', '2015-06-02T00:00:00.000000000',
#        '2015-06-07T00:00:00.000000000', '2015-06-08T00:00:00.000000000',
#        '2015-05-02T00:00:00.000000000', '2015-06-22T00:00:00.000000000',
#        '2015-04-28T00:00:00.000000000', '2015-05-24T00:00:00.000000000',
#        '2015-04-29T00:00:00.000000000', '2015-05-19T00:00:00.000000000',
# ...

# %%
#df['Date']= df['Date']
#df.head()

# %%
(df['Date']==df['Date_month_year']).any()
# Out:
# True

# %%
df= df.drop('Date_month_year',axis=1)

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint       Date  \
# 0   250635                      Comcast Cable Internet Speeds 2015-04-22
# 1   223441       Payment disappear - service got disconnected 2015-04-08
# 2   242732                                  Speed and Service 2015-04-18
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4   307175         Comcast not working and no service to boot 2015-05-26
#
#                  Time        Received Via      City     State  Zip code  \
# 0 2022-10-19 15:53:50  Customer Care Call  Abingdon  Maryland     21009
# 1 2022-10-19 10:22:56            Internet   Acworth   Georgia     30102
# 2 2022-10-19 09:55:47            Internet   Acworth   Georgia     30101
# 3 2022-10-19 11:59:35            Internet   Acworth   Georgia     30101
# 4 2022-10-19 13:25:26            Internet   Acworth   Georgia     30101
#
#    Status Filing on Behalf of Someone
# 0  Closed                          No
# ...

# %%
df['Date'].value_counts()
# Out:
# 2015-06-24    218
# 2015-06-23    190
# 2015-06-25     98
# 2015-06-26     55
# 2015-06-30     53
#              ...
# 2015-05-10      7
# 2015-05-24      7
# 2015-04-05      6
# 2015-04-11      5
# 2015-05-03      5
# Name: Date, Length: 91, dtype: int64

# %%
df1=df[['Date','Customer Complaint']]
df1
# Out:
#            Date                                 Customer Complaint
# 0    2015-04-22                      Comcast Cable Internet Speeds
# 1    2015-04-08       Payment disappear - service got disconnected
# 2    2015-04-18                                  Speed and Service
# 3    2015-05-07  Comcast Imposed a New Usage Cap of 300GB that ...
# 4    2015-05-26         Comcast not working and no service to boot
# ...         ...                                                ...
# 2219 2015-04-02                               Service Availability
# 2220 2015-06-02         Comcast Monthly Billing for Returned Modem
# 2221 2015-06-09                            complaint about comcast
# 2222 2015-06-23             Extremely unsatisfied Comcast customer
# 2223 2015-06-24               Comcast, Ypsilanti MI Internet Speed
#
# [2224 rows x 2 columns]

# %%
df1['Date_Month']=df1['Date'].dt.month
# Out:
# C:\Users\Bhashkar\AppData\Local\Temp\ipykernel_3916\1997206466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Date_Month']=df1['Date'].dt.month

# %%
df1
# Out:
#            Date                                 Customer Complaint  Date_Month
# 0    2015-04-22                      Comcast Cable Internet Speeds           4
# 1    2015-04-08       Payment disappear - service got disconnected           4
# 2    2015-04-18                                  Speed and Service           4
# 3    2015-05-07  Comcast Imposed a New Usage Cap of 300GB that ...           5
# 4    2015-05-26         Comcast not working and no service to boot           5
# ...         ...                                                ...         ...
# 2219 2015-04-02                               Service Availability           4
# 2220 2015-06-02         Comcast Monthly Billing for Returned Modem           6
# 2221 2015-06-09                            complaint about comcast           6
# 2222 2015-06-23             Extremely unsatisfied Comcast customer           6
# 2223 2015-06-24               Comcast, Ypsilanti MI Internet Speed           6
#
# [2224 rows x 3 columns]

# %%
df1['Date_Month'].value_counts(sort=False).rename(index={4:'April',5:'May',6:'June'}).plot(kind='line')
# Out:
# <AxesSubplot: >

# %%
#df['Customer Complaint'].value_counts()

# %%
df_table = pd.value_counts(df['Customer Complaint']).to_frame().reset_index()
df_table
# Out:
#                                               index  Customer Complaint
# 0                                           Comcast                  83
# 1                                  Comcast Internet                  18
# 2                                  Comcast Data Cap                  17
# 3                                           comcast                  13
# 4                                   Comcast Billing                  11
# ...                                             ...                 ...
# 1836  Improper Billing and non resolution of issues                   1
# 1837                                Deceptive trade                   1
# 1838                          intermittent internet                   1
# 1839          Internet Speed on Wireless Connection                   1
# 1840           Comcast, Ypsilanti MI Internet Speed                   1
#
# [1841 rows x 2 columns]

# %%
df_table= df_table.rename(columns={'index': 'Complaint Type', 'Customer Complaint':'Frequency'})
df_table
# Out:
#                                      Complaint Type  Frequency
# 0                                           Comcast         83
# 1                                  Comcast Internet         18
# 2                                  Comcast Data Cap         17
# 3                                           comcast         13
# 4                                   Comcast Billing         11
# ...                                             ...        ...
# 1836  Improper Billing and non resolution of issues          1
# 1837                                Deceptive trade          1
# 1838                          intermittent internet          1
# 1839          Internet Speed on Wireless Connection          1
# 1840           Comcast, Ypsilanti MI Internet Speed          1
#
# [1841 rows x 2 columns]

# %%
df['Status'].value_counts()
# Out:
# Solved     973
# Closed     734
# Open       363
# Pending    154
# Name: Status, dtype: int64

# %%
df['Closed']= df['Status']
df.columns
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Time', 'Received Via',
#        'City', 'State', 'Zip code', 'Status', 'Filing on Behalf of Someone',
#        'Closed', 'Open'],
#       dtype='object')

# %%
df['Open']= df['Status']

# %%
df['Open'] = df ['Open'].replace ('Closed',np.nan)

# %%
df['Open'] = df ['Open'].replace ('Solved',np.nan)

# %%
df['Closed'] = df ['Closed'].replace ('Open',np.nan)

# %%
df['Closed'] = df ['Closed'].replace ('Pending',np.nan)

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
df['City'].value_counts()
# Out:
# Atlanta         63
# Chicago         47
# Knoxville       36
# Houston         33
# Jacksonville    31
#                 ..
# Howell           1
# Hudsonville      1
# Hughesville      1
# Huston           1
# Logan            1
# Name: City, Length: 928, dtype: int64

# %%
#fig, ax = plt.subplots(figsize=(25,20))
#ax.bar(df['City'].value_counts(),df['City'].value_counts().keys())
#ax.set_xlabel('Proportion of non-retail business acres per town')
#ax.set_ylabel('Full-value property-tax rate per $10,000')
#plt.show()

# %%
df['Closed'].unique()
# Out:
# array(['Closed', nan, 'Solved'], dtype=object)

# %%
df['Open'].unique()
# Out:
# array([nan, 'Open', 'Pending'], dtype=object)

# %%
#plt.bar(df['City'],df['Closed'].value_counts())
#ply.bar(df['City'],df['Open'].value_counts())
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [95], line 1
# ----> 1 plt.bar(df['City'],df['Closed'].value_counts())
#       2 ply.bar(df['City'],df['Open'].value_counts())
#       3 plt.show()
#
# File C:\Python310\lib\site-packages\matplotlib\pyplot.py:2357, in bar(x, height, width, bottom, align, data, **kwargs)
#    2353 @_copy_docstring_and_deprecators(Axes.bar)
#    2354 def bar(
#    2355         x, height, width=0.8, bottom=None, *, align='center',
#    2356         data=None, **kwargs):
# -> 2357     return gca().bar(
#    2358         x, height, width=width, bottom=bottom, align=align,
#    2359         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\Python310\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
# ...
